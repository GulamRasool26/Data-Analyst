# %% [markdown]
# # Web Scraping 1

# %% [markdown]
# ### Inspecting HTML Webpages Using Python

# %%
<html> // Main HTML tag that defines the document as an HTML document

<head> // The head tag that contains meta-information about the document, such as the title and links to stylesheets or scripts

    <title>Document</title> // The title of the document that appears in the browser tab

</head>

<body> // The body tag that contains the content of the webpage

    <h1>My First HTML Page</h1> // Heading 1 tag that defines the main heading of the page

    <p><b>hello world wide web</b></p>  // Paragraph tag that contains bold text
    
    <p><i>This is an italicized text.</i></p> // Paragraph tag that contains italicized text
    
    <p><u>This is an underlined text.</u></p> // Paragraph tag that contains underlined text
    
    <p>This is my first web page</p> // Paragraph tag that contains regular text
    
    <p>html tag cab give <b><i>various</i></b>
    <u>looks and formats</u> to the content of this webpage</p> // Paragraph tag that contains a combination of bold, italicized, and underlined text

</body>

</html>

# %%
inspecting tables in html at
scrapethisite.com page and forms in html
